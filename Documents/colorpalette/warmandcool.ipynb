# %% [markdown]
# # a notebook to figure out warm and cool ranges

# %%
import pandas as pd
import colorsys

# %%
pwd
# Out:
# '/Users/waverlywang/Documents/CS189'

# %%
df = pd.read_csv('skincolors.csv')

# %%
df.head()
# Out:
#       Unnamed: 0         category W or C          RGB
# 0  bright spring      fair (I) NW   warm  253,227,204
# 1            NaN       fair (I) N   warm  244,217,200
# 2            NaN      light(II) N   warm  236,207,167
# 3            NaN    light (II) NW   warm  236,210,167
# 4            NaN  medium (III) NW   warm  225,174,127

# %%
df.dropna(subset = ["W or C", "RGB", "category"])
# Out:
#        Unnamed: 0         category W or C          RGB
# 0   bright spring      fair (I) NW   warm  253,227,204
# 1             NaN       fair (I) N   warm  244,217,200
# 2             NaN      light(II) N   warm  236,207,167
# 3             NaN    light (II) NW   warm  236,210,167
# 4             NaN  medium (III) NW   warm  225,174,127
# ..            ...              ...    ...          ...
# 67            NaN  medium (III) NC   cool  217,169,134
# 68            NaN       medium (N)   cool  224,169,129
# 69            NaN      deep (VI) C   cool     73,51,55
# 70            NaN     deep (VI) NC   cool     82,50,48
# 71            NaN      deep (VI) N   cool     87,51,44
#
# [65 rows x 4 columns]

# %%
def findmax():
    # find max and min of warm and cool overall
    warmLOL = []
    coolLOL = []
    for index, row in df.iterrows():
        
        # if spreadsheet[row]["W or C"] == "warm":
        colors = row["RGB"]
        if type(colors) == str:
  
            colors = colors.replace(")", "")
            colors = colors.replace("(", "")
            r,g,b = colors.split(",")
            

            r = int(r)
            g = int(g)
            b = int(b)
        if row["W or C"] == "warm":
            warmLOL += [(colorsys.rgb_to_hsv(r, g, b))[0]]
        elif row["W or C"] == "cool":
            coolLOL += [(colorsys.rgb_to_hsv(r, g, b))[0]]
    print(max(warmLOL), "max warm")
    print(min(warmLOL), "min warm")
    print(max(coolLOL), "max cool")
    print(min(coolLOL), "min cool")
            # warmLOL += [spreadsheet[row]["RGB"]]

# %%
findmax()
# Out:
# 0.11190476190476191 max warm
# 0.027131782945736427 min warm
# 0.9696969696969697 max cool
# 0.0 min cool

# %% [markdown]
# ## finding what's warm and cool for dark or light

# %%
def maxofdarklight(df):
    darkwarmhues = []
    darkcoolhues = []
    lightwarmhues = []
    lightcoolhues = []
    for index, row in df.iterrows():

            # if spreadsheet[row]["W or C"] == "warm":
            colors = row["RGB"]
            if type(colors) == str:
    
                colors = colors.replace(")", "")
                colors = colors.replace("(", "")
                r,g,b = colors.split(",")
                

                r = int(r)
                g = int(g)
                b = int(b)   
            h,s,v = colorsys.rgb_to_hsv(r, g, b)

            halfwaybt80and255 = (80+255)/2
            xmin = 80
            xmax = 255


            if 80 < v and v < halfwaybt80and255: #you are dark if you have low value 
                # print("dark")
                if row["W or C"] == "warm":
                    darkwarmhues += [h]
                elif row["W or C"] == "cool":
                    darkcoolhues += [h]
            elif v > halfwaybt80and255:
                # print("light")
                if row["W or C"] == "warm":
                    lightwarmhues += [h]
                elif row["W or C"] == "cool":
                    lightcoolhues += [h]
    
    print(f'the min - max warm value of dark skin is {min(darkwarmhues)} - {max(darkwarmhues)}')
 
    print(f'the min - max cool value of dark skin is {min(darkcoolhues)} - {max(darkcoolhues)}')
 
    print(f'the min - max warm value of light skin is {min(lightwarmhues)} - {max(lightwarmhues)}')

    print(f'the min - max cool value of light skin is {min(lightcoolhues)} - {max(lightcoolhues)}')

# %%
maxofdarklight(df)
# Out:
# the min - max warm value of dark skin is 0.027131782945736427 - 0.07647058823529412
# the min - max cool value of dark skin is 0.0 - 0.027272727272727282
# the min - max warm value of light skin is 0.05092592592592593 - 0.11190476190476191
# the min - max cool value of light skin is 0.05092592592592593 - 0.0966183574879227

# %% [markdown]
# # or find what 's dark or light for
#
# fair, medium, light, tan, deep, dark

# %%
def warmcoolskins(df):
    fairwarmhues = []
    faircoolhues = []
    fairvalues = []
    lightwarmhues = []
    lightcoolhues = []
    lightvalues = []
    mediumwarmhues = []
    mediumcoolhues = []
    mediumvalues = []
    tanwarmhues = []
    tancoolhues = []
    tanvalues = []
    darkwarmhues = []
    darkcoolhues = []
    darkvalues = []
    deepwarmhues = []
    deepcoolhues = []
    deepvalues = []
    for index, row in df.iterrows():

            # if spreadsheet[row]["W or C"] == "warm":
            colors = row["RGB"]
            if type(colors) == str:
    
                colors = colors.replace(")", "")
                colors = colors.replace("(", "")
                r,g,b = colors.split(",")
                

                r = int(r)
                g = int(g)
                b = int(b)   
            h,s,v = colorsys.rgb_to_hsv(r, g, b)

            halfwaybt80and255 = (80+255)/2
            xmin = 80
            xmax = 255

            
            if "fair" in str(row["category"]): #you are dark if you have low value 
                # print("dark")
                fairvalues += [v]
                if row["W or C"] == "warm":
                    fairwarmhues += [h]
                elif row["W or C"]  == "cool":
                    faircoolhues += [h]
            elif "light" in str(row["category"]):
                lightvalues += [v]
                # print("light")
                if row["W or C"]  == "warm":
                    lightwarmhues += [h]
                elif row["W or C"] == "cool":
                    lightcoolhues += [h]
            elif "medium" in str(row["category"]):
                mediumvalues += [v]
                # print("light")
                if row["W or C"]  == "warm":
                    mediumwarmhues += [h]
                elif row["W or C"] == "cool":
                    mediumcoolhues += [h]
            elif "tan" in str(row["category"]):
                tanvalues += [v]
                # print("light")
                if row["W or C"]  == "warm":
                    tanwarmhues += [h]
                elif row["W or C"] == "cool":
                    tancoolhues += [h]
            elif "dark" in str(row["category"]):
                darkvalues += [v]
                # print("light")
                if row["W or C"]  == "warm":
                    darkwarmhues += [h]
                elif row["W or C"] == "cool":
                    darkcoolhues += [h]
            elif "deep" in str(row["category"]):
                deepvalues += [v]
                # print("light")
                if row["W or C"]  == "warm":
                    deepwarmhues += [h]
                elif row["W or C"] == "cool":
                    deepcoolhues += [h]
    print(f'the min and max warm hue value of fair skin is {min(fairwarmhues)} - {max(fairwarmhues)}')
    print(f'the min and max cool hue value of fair skin is {min(faircoolhues)} - {max(faircoolhues)}')
    print(f'the min and max value of fair skin is {min(fairvalues)} - {max(fairvalues)}')
    print("\n")
    print(f'the min and max warm hue value of light skin is {min(lightwarmhues)} - {max(lightwarmhues)}')
    print(f'the min and max cool hue value of light skin is {min(lightcoolhues)} - {max(lightcoolhues)}')
    print(f'the min and max value of light skin is {min(lightvalues)} - {max(lightvalues)}')
    print("\n")
    print(f'the min and max warm hue value of med skin is {min(mediumwarmhues)} - {max(mediumwarmhues)}')
    print(f'the min and max cool hue value of med skin is {min(mediumcoolhues)} - {max(mediumcoolhues)}')
    print(f'the min and max value of medium skin is {min(mediumvalues)} - {max(mediumvalues)}')
    print("\n")
    print(f'the min and max warm hue value of tan skin is {min(tanwarmhues)} - {max(tanwarmhues)}')
    print(f'the min and max cool hue value of tan skin is {min(tancoolhues)} - {max(tancoolhues)}')
    print(f'the min and max value of tan skin is {min(tanvalues)} - {max(tanvalues)}')
    print("\n")
    print(f'the min and max warm hue value of dark skin is {min(darkwarmhues)} - {max(darkwarmhues)}')
    print(f'the min and max cool hue value of dark skin is {min(darkcoolhues)} - {max(darkcoolhues)}')
    print(f'the min and max value of dark skin is {min(darkvalues)} - {max(darkvalues)}')
    print("\n")
    print(f'the min and max warm hue value of deep skin is {min(deepwarmhues)} - {max(deepwarmhues)}')
    print(f'the min and max cool hue value of deep skin is {min(deepcoolhues)} - {max(deepcoolhues)}')
    print(f'the min and max value of deep skin is {min(deepvalues)} - {max(deepvalues)}')
    print("\n")
    print("\n")

# %%
warmcoolskins(df)
# Out:
# the min and max warm hue value of fair skin is 0.06439393939393939 - 0.11190476190476191
# the min and max cool hue value of fair skin is 0.06439393939393939 - 0.07407407407407407
# the min and max value of fair skin is 236 - 253
#
#
# the min and max warm hue value of light skin is 0.07647058823529412 - 0.11190476190476191
# the min and max cool hue value of light skin is 0.09408602150537633 - 0.0966183574879227
# the min and max value of light skin is 130 - 236
#
#
# the min and max warm hue value of med skin is 0.07017543859649122 - 0.08934707903780069
# the min and max cool hue value of med skin is 0.0641025641025641 - 0.07028112449799197
# the min and max value of medium skin is 130 - 225
#
#
# the min and max warm hue value of tan skin is 0.05092592592592593 - 0.07647058823529412
# the min and max cool hue value of tan skin is 0.05092592592592593 - 0.06481481481481481
# the min and max value of tan skin is 130 - 201
#
#
# ...
